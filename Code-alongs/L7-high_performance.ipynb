# %%
import pandas as pd

athlete_events = pd.read_csv("../Data/athlete_events.csv")

# %%
athlete_events[athlete_events['NOC'] == "SWE"]
# Out:
#             ID                        Name Sex   Age  Height  Weight    Team  \
# 725        414                  Arvid berg   M  26.0     NaN     NaN  Sweden
# 726        415        Bjrn Olof Conny berg   M  23.0   181.0    76.0  Sweden
# 727        416             Nils Georg berg   M  19.0   181.0    78.0  Sweden
# 728        416             Nils Georg berg   M  19.0   181.0    78.0  Sweden
# 729        417            Sara Helena berg   F  17.0   190.0    73.0  Sweden
# ...        ...                         ...  ..   ...     ...     ...     ...
# 268630  134390  Bertz Erik Olov Zetterberg   M  25.0     NaN     NaN  Sweden
# 268631  134391      Carl Henrik Zetterberg   M  21.0   183.0    86.0  Sweden
# 268632  134391      Carl Henrik Zetterberg   M  25.0   183.0    86.0  Sweden
# 268633  134391      Carl Henrik Zetterberg   M  29.0   183.0    86.0  Sweden
# 268634  134391      Carl Henrik Zetterberg   M  33.0   183.0    86.0  Sweden
#
# ...
